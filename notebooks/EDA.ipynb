# %%
# Creating graphs 

import pandas as pd 
import plotly.express as px 

car_Date = pd.read_csv('vehicles_us.csv') # reading data
fig =px.histogram(car_Data, x ="odometer") # creating histogram 
fig.show()
